# %%
import asyncio
import websockets
import json
import time
import warnings
import pandas as pd

from datetime import datetime, timezone

# Ignore warnings
warnings.filterwarnings('ignore')

# %%
# Define dataframes columns 
position_columns=['Message.PositionReport.Cog',
    'Message.PositionReport.Latitude', 'Message.PositionReport.Longitude',
    'Message.PositionReport.NavigationalStatus',
    'Message.PositionReport.PositionAccuracy',
    'Message.PositionReport.RateOfTurn', 'Message.PositionReport.Sog',
    'Message.PositionReport.TrueHeading', 'MetaData.MMSI',
    'MetaData.ShipName', 'MetaData.time_utc']

position_exclude = ["MessageType", "Message.PositionReport.CommunicationState", 
    "MetaData.MMSI_String", 'MetaData.latitude', 'MetaData.longitude',
    'Message.PositionReport.MessageID', 'Message.PositionReport.Raim', 
    'Message.PositionReport.Timestamp', 'Message.PositionReport.RepeatIndicator', 
    "Message.PositionReport.Spare", 'Message.PositionReport.UserID',
    'Message.PositionReport.Valid', 'Message.PositionReport.SpecialManoeuvreIndicator']

ship_data_columns = [
       'Message.ShipStaticData.CallSign', 'Message.ShipStaticData.Destination',
       'Message.ShipStaticData.Eta.Day', 'Message.ShipStaticData.Eta.Hour',
       'Message.ShipStaticData.Eta.Minute', 'Message.ShipStaticData.Eta.Month',
       'Message.ShipStaticData.ImoNumber',
       'Message.ShipStaticData.Name', 'Message.ShipStaticData.Type', 
       'MetaData.MMSI',  
       'MetaData.latitude', 'MetaData.longitude', 'MetaData.time_utc']

ship_data_exclude = ['MessageType', 'Message.ShipStaticData.AisVersion',
    'Message.ShipStaticData.Dte', 'Message.ShipStaticData.Dimension.A',
    'Message.ShipStaticData.Dimension.B', 'Message.ShipStaticData.Dimension.C',
    'Message.ShipStaticData.Dimension.D', 'Message.ShipStaticData.FixType',
    'Message.ShipStaticData.MaximumStaticDraught',
    'Message.ShipStaticData.MessageID', 'Message.ShipStaticData.RepeatIndicator',
    'Message.ShipStaticData.Spare', 'Message.ShipStaticData.UserID', 'MetaData.ShipName',
    'MetaData.MMSI_String', 'Message.ShipStaticData.Valid'
]

# %%
async def connect_ais_stream():
    
    # Instantiate output Dataframes
    position_df = pd.DataFrame(columns=position_columns)
    ship_data_df = pd.DataFrame(columns=ship_data_columns)
    
    # Set timeout
    timeout = time.time() + 60*60*24
    
    # Connect websocket to AISStream
    async with websockets.connect("wss://stream.aisstream.io/v0/stream") as websocket:
        
        # Subscribe with personal APIKey and Coordinates bounding the Laconian Gulf
        subscribe_message = {"APIKey": PRIVATE_KEY,
                             "BoundingBoxes": [[[36.86687546866755, 22.184442828560584], 
                                                [36.199014645278616, 23.13974778084953]]]} 

        subscribe_message_json = json.dumps(subscribe_message)
        await websocket.send(subscribe_message_json)
        
        # Process websocket messages
        async for message_json in websocket:
            
            # Load the JSON and convert to Pandas datafram
            message = json.loads(message_json)
            message_df = pd.json_normalize(message)
            
            # Processing if the message is a position report
            if message_df["MessageType"][0] == "PositionReport":
                
                # Add message to the results dataframe 
                message_df.drop(columns=position_exclude, inplace=True)
                position_df = pd.concat([position_df, message_df], ignore_index=True)
                
                # Print execution status every time 100 rows are stored
                if len(position_df) % 100 == 0:
                    time_remaining = round((timeout - time.time()) / 60, 1)
                    print(f"Time to finish: {time_remaining}")
                    print(f"Position messages extracted: {len(position_df)}")
            
            # Processing if the message is Ship Static Data
            elif message_df["MessageType"][0] == "ShipStaticData":
                
                message_df.drop(columns=ship_data_exclude, inplace=True)
                ship_data_df = pd.concat([ship_data_df, message_df], ignore_index=True)
        
            # Timeout exit 
            if time.time() > timeout:
                return position_df, ship_data_df

# %%
position_day1, ship_data_day1 = await connect_ais_stream()

position_day1.to_csv("Data/position_day1.csv")
ship_data_day1.to_csv("Data/ship_data_day1.csv")

# %%
# Storage predicted calculation
min5 = position_day1.memory_usage(index=True, deep=True).sum()
hora = min5 * 12
dia = hora * 24
weekday = dia * 5

print(hora)
print(dia)
print(weekday)

# %%
position_day2, ship_data_day2 = await connect_ais_stream()

position_day2.to_csv("Data/position_day2.csv")
ship_data_day2.to_csv("Data/ship_data_day2.csv")

# %%
position_day3, ship_data_day3 = await connect_ais_stream()

position_day3.to_csv("Data/position_day3.csv")
ship_data_day3.to_csv("Data/ship_data_day3.csv")

# %%
position_day4, ship_data_day4 = await connect_ais_stream()

position_day4.to_csv("Data/position_day4.csv")
ship_data_day4.to_csv("Data/ship_data_day4.csv")

# %%
position_day5, ship_data_day5 = await connect_ais_stream()

position_day5.to_csv("Data/position_day5.csv")
ship_data_day5.to_csv("Data/ship_data_day5.csv")

# %%
position_day6, ship_data_day6 = await connect_ais_stream()

position_day6.to_csv("Data/position_day6.csv")
ship_data_day6.to_csv("Data/ship_data_day6.csv")

# %%
position_day7, ship_data_day7 = await connect_ais_stream()

position_day7.to_csv("Data/position_day7.csv")
ship_data_day7.to_csv("Data/ship_data_day7.csv")

# %%
position_day8, ship_data_day8 = await connect_ais_stream()

position_day8.to_csv("Data/position_day8.csv")
ship_data_day8.to_csv("Data/ship_data_day8.csv")

# %%
position_day9, ship_data_day9 = await connect_ais_stream()

position_day9.to_csv("Data/position_day9.csv")
ship_data_day9.to_csv("Data/ship_data_day9.csv")

# %%
position_day11, ship_data_day11 = await connect_ais_stream()

position_day11.to_csv("Data/position_day11.csv")
ship_data_day11.to_csv("Data/ship_data_day11.csv")

# %%
position_day12, ship_data_day12 = await connect_ais_stream()

position_day12.to_csv("Data/position_day12.csv")
ship_data_day12.to_csv("Data/ship_data_day12.csv")

# %%
position_day13, ship_data_day13 = await connect_ais_stream()

position_day13.to_csv("Data/position_day13.csv")
ship_data_day13.to_csv("Data/ship_data_day13.csv")

# %%
position_day14, ship_data_day14 = await connect_ais_stream()

position_day14.to_csv("Data/position_day14.csv")
ship_data_day14.to_csv("Data/ship_data_day14.csv")

# %%
position_day15, ship_data_day15 = await connect_ais_stream()

position_day15.to_csv("Data/position_day15.csv")
ship_data_day15.to_csv("Data/ship_data_day15.csv")
# Out:
# Time to finish: 1434.9
# Position messages extracted: 100
# Time to finish: 1428.3
# Position messages extracted: 200
# Time to finish: 1422.3
# Position messages extracted: 300
# Time to finish: 1416.1
# Position messages extracted: 400
# Time to finish: 1410.0
# Position messages extracted: 500
# Time to finish: 1404.8
# Position messages extracted: 600
# Time to finish: 1398.2
# Position messages extracted: 700
# Time to finish: 1392.8
# Position messages extracted: 800
# Time to finish: 1386.4
# Position messages extracted: 900
# Time to finish: 1381.0
# Position messages extracted: 1000
# Time to finish: 1375.5
# Position messages extracted: 1100
# Time to finish: 1369.7
# Position messages extracted: 1200
# Time to finish: 1363.5
# Position messages extracted: 1300
# Time to finish: 1358.1
# Position messages extracted: 1400
# Time to finish: 1351.9
# Position messages extracted: 1500
# Time to finish: 1345.4
# Position messages extracted: 1600
# Time to finish: 1338.9
# Position messages extracted: 1700
# Time to finish: 1332.1
# Position messages extracted: 1800
# Time to finish: 1325.8
# Position messages extracted: 1900
# Time to finish: 1319.4
# Position messages extracted: 2000
# Time to finish: 1312.2
# Position messages extracted: 2100
# Time to finish: 1304.8
# Position messages extracted: 2200
# Time to finish: 1297.6
# Position messages extracted: 2300
# Time to finish: 1289.7
# Position messages extracted: 2400
# Time to finish: 1282.2
# Position messages extracted: 2500
# Time to finish: 1274.5
# Position messages extracted: 2600
# Time to finish: 1265.2
# Position messages extracted: 2700
# Time to finish: 1257.3
# Position messages extracted: 2800
# Time to finish: 1250.0
# Position messages extracted: 2900
# Time to finish: 1242.6
# Position messages extracted: 3000
# Time to finish: 1235.2
# Position messages extracted: 3100
# Time to finish: 1228.0
# Position messages extracted: 3200
# Time to finish: 1220.4
# Position messages extracted: 3300
# Time to finish: 1212.5
# Position messages extracted: 3400
# Time to finish: 1205.1
# Position messages extracted: 3500
# Time to finish: 1198.4
# Position messages extracted: 3600
# Time to finish: 1192.0
# Position messages extracted: 3700
# Time to finish: 1185.8
# Position messages extracted: 3800
# Time to finish: 1179.9
# Position messages extracted: 3900
# Time to finish: 1173.5
# Position messages extracted: 4000
# Time to finish: 1168.1
# Position messages extracted: 4100
# Time to finish: 1162.2
# Position messages extracted: 4200
# Time to finish: 1156.4
# Position messages extracted: 4300
# Time to finish: 1151.7
# Position messages extracted: 4400
# Time to finish: 1146.8
# Position messages extracted: 4500
# Time to finish: 1140.7
# Position messages extracted: 4600
# Time to finish: 1134.4
# Position messages extracted: 4700
# Time to finish: 1128.4
# Position messages extracted: 4800
# Time to finish: 1122.9
# Position messages extracted: 4900
# Time to finish: 1117.2
# Position messages extracted: 5000
# Time to finish: 1112.1
# Position messages extracted: 5100
# Time to finish: 1106.6
# Position messages extracted: 5200
# Time to finish: 1101.3
# Position messages extracted: 5300
# Time to finish: 1096.1
# Position messages extracted: 5400
# Time to finish: 1090.5
# Position messages extracted: 5500
# Time to finish: 1084.9
# Position messages extracted: 5600
# Time to finish: 1078.4
# Position messages extracted: 5700
# Time to finish: 1071.8
# Position messages extracted: 5800
# Time to finish: 1065.3
# Position messages extracted: 5900
# Time to finish: 1058.6
# Position messages extracted: 6000
# Time to finish: 1051.4
# Position messages extracted: 6100
# Time to finish: 1044.1
# Position messages extracted: 6200
# Time to finish: 1036.2
# Position messages extracted: 6300
# Time to finish: 1029.3
# Position messages extracted: 6400
# Time to finish: 1022.1
# Position messages extracted: 6500
# Time to finish: 1016.4
# Position messages extracted: 6600
# Time to finish: 1009.1
# Position messages extracted: 6700
# Time to finish: 1001.9
# Position messages extracted: 6800
# Time to finish: 995.2
# Position messages extracted: 6900
# Time to finish: 988.2
# Position messages extracted: 7000
# Time to finish: 981.2
# Position messages extracted: 7100
# Time to finish: 972.4
# Position messages extracted: 7200
# Time to finish: 964.2
# Position messages extracted: 7300
# Time to finish: 956.5
# Position messages extracted: 7400
# Time to finish: 949.2
# Position messages extracted: 7500
# Time to finish: 942.3
# Position messages extracted: 7600
# Time to finish: 934.3
# Position messages extracted: 7700
# Time to finish: 927.4
# Position messages extracted: 7800
# Time to finish: 920.2
# Position messages extracted: 7900
# Time to finish: 913.3
# Position messages extracted: 8000
# Time to finish: 907.2
# Position messages extracted: 8100
# Time to finish: 901.1
# Position messages extracted: 8200
# Time to finish: 895.4
# Position messages extracted: 8300
# Time to finish: 890.2
# Position messages extracted: 8400
# Time to finish: 885.3
# Position messages extracted: 8500
# Time to finish: 880.4
# Position messages extracted: 8600
# Time to finish: 875.2
# Position messages extracted: 8700
# Time to finish: 870.5
# Position messages extracted: 8800
# Time to finish: 865.9
# Position messages extracted: 8900
# Time to finish: 860.9
# Position messages extracted: 9000
# Time to finish: 855.8
# Position messages extracted: 9100
# Time to finish: 851.2
# Position messages extracted: 9200
# Time to finish: 846.5
# Position messages extracted: 9300
# Time to finish: 842.0
# Position messages extracted: 9400
# Time to finish: 837.1
# Position messages extracted: 9500
# Time to finish: 831.8
# Position messages extracted: 9600
# Time to finish: 827.0
# Position messages extracted: 9700
# Time to finish: 821.7
# Position messages extracted: 9800
# Time to finish: 817.0
# Position messages extracted: 9900
# Time to finish: 811.6
# Position messages extracted: 10000
# Time to finish: 806.4
# Position messages extracted: 10100
# Time to finish: 801.2
# Position messages extracted: 10200
# Time to finish: 796.2
# Position messages extracted: 10300
# Time to finish: 791.3
# Position messages extracted: 10400
# Time to finish: 786.1
# Position messages extracted: 10500
# Time to finish: 781.3
# Position messages extracted: 10600
# Time to finish: 776.3
# Position messages extracted: 10700
# Time to finish: 771.2
# Position messages extracted: 10800
# Time to finish: 765.2
# Position messages extracted: 10900
# Time to finish: 759.8
# Position messages extracted: 11000
# Time to finish: 753.4
# Position messages extracted: 11100
# Time to finish: 748.1
# Position messages extracted: 11200
# Time to finish: 741.2
# Position messages extracted: 11300
# Time to finish: 735.0
# Position messages extracted: 11400
# Time to finish: 728.3
# Position messages extracted: 11500
# Time to finish: 721.0
# Position messages extracted: 11600
# Time to finish: 715.0
# Position messages extracted: 11700
# Time to finish: 708.3
# Position messages extracted: 11800
# Time to finish: 701.8
# Position messages extracted: 11900
# Time to finish: 695.2
# Position messages extracted: 12000
# Time to finish: 689.3
# Position messages extracted: 12100
# Time to finish: 683.9
# Position messages extracted: 12200
# Time to finish: 678.8
# Position messages extracted: 12300
# Time to finish: 673.3
# Position messages extracted: 12400
# Time to finish: 668.3
# Position messages extracted: 12500
# Time to finish: 662.5
# Position messages extracted: 12600
# Time to finish: 657.7
# Position messages extracted: 12700
# Time to finish: 653.3
# Position messages extracted: 12800
# Time to finish: 648.5
# Position messages extracted: 12900
# Time to finish: 644.3
# Position messages extracted: 13000
# Time to finish: 639.6
# Position messages extracted: 13100
# Time to finish: 634.6
# Position messages extracted: 13200
# Time to finish: 629.5
# Position messages extracted: 13300
# Time to finish: 624.7
# Position messages extracted: 13400
# Time to finish: 620.0
# Position messages extracted: 13500
# Time to finish: 615.1
# Position messages extracted: 13600
# Time to finish: 610.8
# Position messages extracted: 13700
# Time to finish: 606.1
# Position messages extracted: 13800
# Time to finish: 601.0
# Position messages extracted: 13900
# Time to finish: 595.7
# Position messages extracted: 14000
# Time to finish: 590.4
# Position messages extracted: 14100
# Time to finish: 585.5
# Position messages extracted: 14200
# Time to finish: 580.3
# Position messages extracted: 14300
# Time to finish: 575.2
# Position messages extracted: 14400
# Time to finish: 570.1
# Position messages extracted: 14500
# Time to finish: 565.2
# Position messages extracted: 14600
# Time to finish: 560.0
# Position messages extracted: 14700
# Time to finish: 554.9
# Position messages extracted: 14800
# Time to finish: 549.9
# Position messages extracted: 14900
# Time to finish: 544.7
# Position messages extracted: 15000
# Time to finish: 540.0
# Position messages extracted: 15100
# Time to finish: 535.0
# Position messages extracted: 15200
# Time to finish: 529.6
# Position messages extracted: 15300
# Time to finish: 524.4
# Position messages extracted: 15400
# Time to finish: 519.2
# Position messages extracted: 15500
# Time to finish: 514.4
# Position messages extracted: 15600
# Time to finish: 509.3
# Position messages extracted: 15700
# Time to finish: 503.6
# Position messages extracted: 15800
# Time to finish: 498.1
# Position messages extracted: 15900
# Time to finish: 492.4
# Position messages extracted: 16000
# Time to finish: 487.0
# Position messages extracted: 16100
# Time to finish: 481.5
# Position messages extracted: 16200
# Time to finish: 473.5
# Position messages extracted: 16300
# Time to finish: 467.4
# Position messages extracted: 16400
# Time to finish: 461.3
# Position messages extracted: 16500
# Time to finish: 455.1
# Position messages extracted: 16600
# Time to finish: 449.7
# Position messages extracted: 16700
# Time to finish: 443.5
# Position messages extracted: 16800
# Time to finish: 438.3
# Position messages extracted: 16900
# Time to finish: 432.3
# Position messages extracted: 17000
# Time to finish: 427.2
# Position messages extracted: 17100
# Time to finish: 422.0
# Position messages extracted: 17200
# Time to finish: 417.1
# Position messages extracted: 17300
# Time to finish: 411.6
# Position messages extracted: 17400
# Time to finish: 406.4
# Position messages extracted: 17500
# Time to finish: 401.3
# Position messages extracted: 17600
# Time to finish: 396.0
# Position messages extracted: 17700
# Time to finish: 390.7
# Position messages extracted: 17800
# Time to finish: 385.5
# Position messages extracted: 17900
# Time to finish: 379.8
# Position messages extracted: 18000
# Time to finish: 373.4
# Position messages extracted: 18100
# Time to finish: 367.2
# Position messages extracted: 18200
# Time to finish: 361.4
# Position messages extracted: 18300
# Time to finish: 356.5
# Position messages extracted: 18400
# Time to finish: 350.2
# Position messages extracted: 18500
# Time to finish: 344.7
# Position messages extracted: 18600
# Time to finish: 339.6
# Position messages extracted: 18700
# Time to finish: 334.1
# Position messages extracted: 18800
# Time to finish: 328.3
# Position messages extracted: 18900
# Time to finish: 322.3
# Position messages extracted: 19000
# Time to finish: 316.0
# Position messages extracted: 19100
# Time to finish: 310.3
# Position messages extracted: 19200
# Time to finish: 304.7
# Position messages extracted: 19300
# Time to finish: 299.2
# Position messages extracted: 19400
# Time to finish: 293.4
# Position messages extracted: 19500
# Time to finish: 287.3
# Position messages extracted: 19600
# Time to finish: 282.0
# Position messages extracted: 19700
# Time to finish: 277.2
# Position messages extracted: 19800
# Time to finish: 243.3
# Position messages extracted: 19900
# Time to finish: 240.0
# Position messages extracted: 20000
# Time to finish: 236.3
# Position messages extracted: 20100
# Time to finish: 232.7
# Position messages extracted: 20200
# Time to finish: 228.8
# Position messages extracted: 20300
# Time to finish: 224.5
# Position messages extracted: 20400
# Time to finish: 219.3
# Position messages extracted: 20500
# Time to finish: 213.8
# Position messages extracted: 20600
# Time to finish: 206.7
# Position messages extracted: 20700
# Time to finish: 198.7
# Position messages extracted: 20800
# Time to finish: 192.4
# Position messages extracted: 20900
# Time to finish: 186.1
# Position messages extracted: 21000
# Time to finish: 180.4
# Position messages extracted: 21100
# Time to finish: 175.2
# Position messages extracted: 21200
# Time to finish: 161.6
# Position messages extracted: 21300
# Time to finish: 142.5
# Position messages extracted: 21400
# Time to finish: 134.9
# Position messages extracted: 21500
# Time to finish: 128.1
# Position messages extracted: 21600
# Time to finish: 120.4
# Position messages extracted: 21700
# Time to finish: 105.4
# Position messages extracted: 21800
# Time to finish: 94.6
# Position messages extracted: 21900
# Time to finish: 84.7
# Position messages extracted: 22000
# Time to finish: 76.0
# Position messages extracted: 22100
# Time to finish: 68.4
# Position messages extracted: 22200
# Time to finish: 59.7
# Position messages extracted: 22300
# Time to finish: 50.1
# Position messages extracted: 22400
# Time to finish: 40.9
# Position messages extracted: 22500
# Time to finish: 28.8
# Position messages extracted: 22600
# Time to finish: 19.3
# Position messages extracted: 22700
# Time to finish: 7.3
# Position messages extracted: 22800

# %%
position_day16, ship_data_day16 = await connect_ais_stream()

position_day16.to_csv("Data/position_day16.csv")
ship_data_day16.to_csv("Data/ship_data_day16.csv")
# Out:
# Time to finish: 1344.7
# Position messages extracted: 100
# Time to finish: 1179.2
# Position messages extracted: 200
# Time to finish: 1047.6
# Position messages extracted: 300
# Time to finish: 826.5
# Position messages extracted: 400
# Time to finish: 726.8
# Position messages extracted: 500
# Time to finish: 698.2
# Position messages extracted: 600
# Time to finish: 680.9
# Position messages extracted: 700
# Time to finish: 668.3
# Position messages extracted: 800
# Time to finish: 656.8
# Position messages extracted: 900
# Time to finish: 647.6
# Position messages extracted: 1000
# Time to finish: 639.2
# Position messages extracted: 1100
# Time to finish: 630.3
# Position messages extracted: 1200
# Time to finish: 622.4
# Position messages extracted: 1300
# Time to finish: 612.5
# Position messages extracted: 1400
# Time to finish: 601.8
# Position messages extracted: 1500
# Time to finish: 594.5
# Position messages extracted: 1600
# Time to finish: 586.5
# Position messages extracted: 1700
# Time to finish: 578.8
# Position messages extracted: 1800
# Time to finish: 570.3
# Position messages extracted: 1900
# Time to finish: 560.8
# Position messages extracted: 2000
# Time to finish: 548.7
# Position messages extracted: 2100
# Time to finish: 536.6
# Position messages extracted: 2200
# Time to finish: 525.6
# Position messages extracted: 2300
# Time to finish: 516.5
# Position messages extracted: 2400
# Time to finish: 508.0
# Position messages extracted: 2500
# Time to finish: 498.0
# Position messages extracted: 2600
# Time to finish: 485.9
# Position messages extracted: 2700
# Time to finish: 478.7
# Position messages extracted: 2800
# Time to finish: 474.2
# Position messages extracted: 2900
# Time to finish: 470.4
# Position messages extracted: 3000
# Time to finish: 467.2
# Position messages extracted: 3100
# Time to finish: 463.9
# Position messages extracted: 3200
# Time to finish: 461.0
# Position messages extracted: 3300
# Time to finish: 458.3
# Position messages extracted: 3400
# Time to finish: 455.9
# Position messages extracted: 3500
# Time to finish: 453.4
# Position messages extracted: 3600
# Time to finish: 450.6
# Position messages extracted: 3700
# Time to finish: 448.1
# Position messages extracted: 3800
# Time to finish: 445.5
# Position messages extracted: 3900
# Time to finish: 443.0
# Position messages extracted: 4000
# Time to finish: 440.4
# Position messages extracted: 4100
# Time to finish: 438.0
# Position messages extracted: 4200
# Time to finish: 435.7
# Position messages extracted: 4300
# Time to finish: 433.2
# Position messages extracted: 4400
# Time to finish: 431.0
# Position messages extracted: 4500
# Time to finish: 428.5
# Position messages extracted: 4600
# Time to finish: 426.0
# Position messages extracted: 4700
# Time to finish: 422.7
# Position messages extracted: 4800
# Time to finish: 420.2
# Position messages extracted: 4900
# Time to finish: 417.8
# Position messages extracted: 5000
# Time to finish: 415.3
# Position messages extracted: 5100
# Time to finish: 413.2
# Position messages extracted: 5200
# Time to finish: 411.2
# Position messages extracted: 5300
# Time to finish: 408.7
# Position messages extracted: 5400
# Time to finish: 406.6
# Position messages extracted: 5500
# Time to finish: 404.5
# Position messages extracted: 5600
# Time to finish: 402.3
# Position messages extracted: 5700
# Time to finish: 400.1
# Position messages extracted: 5800
# Time to finish: 398.0
# Position messages extracted: 5900
# Time to finish: 395.6
# Position messages extracted: 6000
# Time to finish: 393.2
# Position messages extracted: 6100
# Time to finish: 390.7
# Position messages extracted: 6200
# Time to finish: 388.5
# Position messages extracted: 6300
# Time to finish: 386.3
# Position messages extracted: 6400
# Time to finish: 384.0
# Position messages extracted: 6500
# Time to finish: 381.8
# Position messages extracted: 6600
# Time to finish: 379.3
# Position messages extracted: 6700
# Time to finish: 376.7
# Position messages extracted: 6800
# Time to finish: 374.5
# Position messages extracted: 6900
# Time to finish: 372.0
# Position messages extracted: 7000
# Time to finish: 369.3
# Position messages extracted: 7100
# Time to finish: 366.8
# Position messages extracted: 7200
# Time to finish: 363.9
# Position messages extracted: 7300
# Time to finish: 361.6
# Position messages extracted: 7400
# Time to finish: 359.0
# Position messages extracted: 7500
# Time to finish: 356.6
# Position messages extracted: 7600
# Time to finish: 353.7
# Position messages extracted: 7700
# Time to finish: 351.3
# Position messages extracted: 7800
# Time to finish: 348.5
# Position messages extracted: 7900
# Time to finish: 346.0
# Position messages extracted: 8000
# Time to finish: 343.5
# Position messages extracted: 8100
# Time to finish: 341.1
# Position messages extracted: 8200
# Time to finish: 338.4
# Position messages extracted: 8300
# Time to finish: 335.7
# Position messages extracted: 8400
# Time to finish: 332.7
# Position messages extracted: 8500
# Time to finish: 330.2
# Position messages extracted: 8600
# Time to finish: 327.6
# Position messages extracted: 8700
# Time to finish: 325.0
# Position messages extracted: 8800
# Time to finish: 322.5
# Position messages extracted: 8900
# Time to finish: 320.0
# Position messages extracted: 9000
# Time to finish: 317.4
# Position messages extracted: 9100
# Time to finish: 314.8
# Position messages extracted: 9200
# Time to finish: 312.4
# Position messages extracted: 9300
# Time to finish: 310.0
# Position messages extracted: 9400
# Time to finish: 307.5
# Position messages extracted: 9500
# Time to finish: 305.0
# Position messages extracted: 9600
# Time to finish: 302.3
# Position messages extracted: 9700
# Time to finish: 299.7
# Position messages extracted: 9800
# Time to finish: 297.3
# Position messages extracted: 9900
# Time to finish: 294.5
# Position messages extracted: 10000
# Time to finish: 292.0
# Position messages extracted: 10100
# Time to finish: 289.0
# Position messages extracted: 10200
# Time to finish: 286.2
# Position messages extracted: 10300
# Time to finish: 283.3
# Position messages extracted: 10400
# Time to finish: 280.5
# Position messages extracted: 10500
# Time to finish: 277.5
# Position messages extracted: 10600
# Time to finish: 275.0
# Position messages extracted: 10700
# Time to finish: 272.0
# Position messages extracted: 10800
# Time to finish: 269.3
# Position messages extracted: 10900
# Time to finish: 266.5
# Position messages extracted: 11000
# Time to finish: 263.7
# Position messages extracted: 11100
# Time to finish: 260.9
# Position messages extracted: 11200
# Time to finish: 257.9
# Position messages extracted: 11300
# Time to finish: 255.3
# Position messages extracted: 11400
# Time to finish: 252.6
# Position messages extracted: 11500
# Time to finish: 249.8
# Position messages extracted: 11600
# Time to finish: 247.1
# Position messages extracted: 11700
# Time to finish: 244.5
# Position messages extracted: 11800
# Time to finish: 241.7
# Position messages extracted: 11900
# Time to finish: 238.7
# Position messages extracted: 12000
# Time to finish: 236.0
# Position messages extracted: 12100
# Time to finish: 233.3
# Position messages extracted: 12200
# Time to finish: 230.5
# Position messages extracted: 12300
# Time to finish: 227.5
# Position messages extracted: 12400
# Time to finish: 224.5
# Position messages extracted: 12500
# Time to finish: 221.5
# Position messages extracted: 12600
# Time to finish: 218.8
# Position messages extracted: 12700
# Time to finish: 216.2
# Position messages extracted: 12800
# Time to finish: 213.0
# Position messages extracted: 12900
# Time to finish: 210.5
# Position messages extracted: 13000
# Time to finish: 207.5
# Position messages extracted: 13100
# Time to finish: 204.7
# Position messages extracted: 13200
# Time to finish: 201.7
# Position messages extracted: 13300
# Time to finish: 198.6
# Position messages extracted: 13400
# Time to finish: 195.9
# Position messages extracted: 13500
# Time to finish: 193.0
# Position messages extracted: 13600
# Time to finish: 190.0
# Position messages extracted: 13700
# Time to finish: 186.7
# Position messages extracted: 13800
# Time to finish: 183.5
# Position messages extracted: 13900
# Time to finish: 180.3
# Position messages extracted: 14000
# Time to finish: 177.2
# Position messages extracted: 14100
# Time to finish: 174.1
# Position messages extracted: 14200
# Time to finish: 171.2
# Position messages extracted: 14300
# Time to finish: 168.1
# Position messages extracted: 14400
# Time to finish: 165.5
# Position messages extracted: 14500
# Time to finish: 162.5
# Position messages extracted: 14600
# Time to finish: 159.5
# Position messages extracted: 14700
# Time to finish: 156.3
# Position messages extracted: 14800
# Time to finish: 152.9
# Position messages extracted: 14900
# Time to finish: 150.1
# Position messages extracted: 15000
# Time to finish: 147.0
# Position messages extracted: 15100
# Time to finish: 144.0
# Position messages extracted: 15200
# Time to finish: 140.8
# Position messages extracted: 15300
# Time to finish: 137.7
# Position messages extracted: 15400
# Time to finish: 134.7
# Position messages extracted: 15500
# Time to finish: 131.8
# Position messages extracted: 15600
# Time to finish: 128.8
# Position messages extracted: 15700
# Time to finish: 125.9
# Position messages extracted: 15800
# Time to finish: 122.6
# Position messages extracted: 15900
# Time to finish: 119.7
# Position messages extracted: 16000
# Time to finish: 116.7
# Position messages extracted: 16100
# Time to finish: 114.0
# Position messages extracted: 16200
# Time to finish: 110.8
# Position messages extracted: 16300
# Time to finish: 107.9
# Position messages extracted: 16400
# Time to finish: 104.8
# Position messages extracted: 16500
# Time to finish: 101.9
# Position messages extracted: 16600
# Time to finish: 99.0
# Position messages extracted: 16700
# Time to finish: 96.1
# Position messages extracted: 16800
# Time to finish: 92.6
# Position messages extracted: 16900
# Time to finish: 89.4
# Position messages extracted: 17000
# Time to finish: 86.3
# Position messages extracted: 17100
# Time to finish: 83.3
# Position messages extracted: 17200
# Time to finish: 80.3
# Position messages extracted: 17300
# Time to finish: 76.8
# Position messages extracted: 17400
# Time to finish: 73.6
# Position messages extracted: 17500
# Time to finish: 70.3
# Position messages extracted: 17600
# Time to finish: 67.1
# Position messages extracted: 17700
# Time to finish: 64.0
# Position messages extracted: 17800
# Time to finish: 60.9
# Position messages extracted: 17900
# Time to finish: 57.9
# Position messages extracted: 18000
# Time to finish: 54.7
# Position messages extracted: 18100
# Time to finish: 51.6
# Position messages extracted: 18200
# Time to finish: 48.5
# Position messages extracted: 18300
# Time to finish: 45.4
# Position messages extracted: 18400
# Time to finish: 41.9
# Position messages extracted: 18500
# Time to finish: 39.0
# Position messages extracted: 18600
# Time to finish: 35.7
# Position messages extracted: 18700
# Time to finish: 32.5
# Position messages extracted: 18800
# Time to finish: 29.4
# Position messages extracted: 18900
# Time to finish: 26.4
# Position messages extracted: 19000
# Time to finish: 23.2
# Position messages extracted: 19100
# Time to finish: 20.1
# Position messages extracted: 19200
# Time to finish: 16.8
# Position messages extracted: 19300
# Time to finish: 13.9
# Position messages extracted: 19400
# Time to finish: 10.8
# Position messages extracted: 19500
# Time to finish: 8.1
# Position messages extracted: 19600
# Time to finish: 5.2
# Position messages extracted: 19700
# Time to finish: 2.3
# Position messages extracted: 19800
